# %%
from google.colab import userdata
userdata.get('form1')
# Out:
# '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'

# %%
# !pip install transformers
# !pip install accelerate
# !pip install torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.5.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.12.14)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import os
from transformers import pipeline
import torch

# %%
access_token = os.environ.get("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", None) or userdata.get('form1')

# %%
from huggingface_hub import login # Import the login function from huggingface_hub

access_token = os.environ.get("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", None) or userdata.get('form1')

login(token=access_token)  # Now the login function is available and should work correctly

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_id = "meta-llama/Meta-Llama-3-8B"

# Load the tokenizer and model directly using the access token
tokenizer = AutoTokenizer.from_pretrained(model_id, use_auth_token=access_token)
model = AutoModelForCausalLM.from_pretrained(model_id, use_auth_token=access_token, torch_dtype=torch.bfloat16, device_map="auto")

# Create the pipeline using the loaded model and tokenizer
pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:810: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0

# %%
# !python3 -m pip install paddlepaddle-gpu
# Out:
# Collecting paddlepaddle-gpu
#   Downloading paddlepaddle_gpu-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (11.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.4.2)
# Collecting astor (from paddlepaddle-gpu)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle-gpu)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.25.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.2.2)
# Downloading paddlepaddle_gpu-2.6.2-cp310-cp310-manylinux1_x86_64.whl (758.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 1.5 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.9 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: opt-einsum, astor, paddlepaddle-gpu
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-gpu-2.6.2

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# Collecting paddleocr>=2.0.1
#   Downloading paddleocr-2.9.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.25.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.4.0)
# Collecting pyclipper (from paddleocr>=2.0.1)
#   Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr>=2.0.1)
#   Downloading lmdb-1.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.67.1)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.26.4)
# Collecting rapidfuzz (from paddleocr>=2.0.1)
#   Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (3.0.11)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (11.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (6.0.2)
# Collecting python-docx (from paddleocr>=2.0.1)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.55.3)
# Collecting fire>=0.3.0 (from paddleocr>=2.0.1)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.32.3)
# Collecting albumentations==1.4.10 (from paddleocr>=2.0.1)
#   Downloading albumentations-1.4.10-py3-none-any.whl.metadata (38 kB)
# Collecting albucore==0.0.13 (from paddleocr>=2.0.1)
#   Downloading albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.13->paddleocr>=2.0.1) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (1.6.0)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.10->paddleocr>=2.0.1) (2.10.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.5.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (3.10.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr>=2.0.1) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr>=2.0.1) (2024.12.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr>=2.0.1) (2.27.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr>=2.0.1) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Downloading paddleocr-2.9.1-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 16.5 MB/s eta 0:00:00
# Downloading albucore-0.0.13-py3-none-any.whl (8.5 kB)
# Downloading albumentations-1.4.10-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 14.6 MB/s eta 0:00:00
# Downloading lmdb-1.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 27.5 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 42.2 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 22.6 MB/s eta 0:00:00
# Downloading rapidfuzz-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.3 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=1b76c2b7e75934ad0d49615e4d8897328d9e8e9427bc6fb86300cad5341ba528
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rapidfuzz, python-docx, fire, albucore, albumentations, paddleocr
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# Successfully installed albucore-0.0.13 albumentations-1.4.10 fire-0.7.0 lmdb-1.6.2 paddleocr-2.9.1 pyclipper-1.3.0.post6 python-docx-1.1.2 rapidfuzz-3.11.0

# %%
from paddleocr import PaddleOCR,draw_ocr

ocr = PaddleOCR(use_angle_cls=True, lang='en')

from google.colab.patches import cv2_imshow
import cv2
import json
import numpy as np
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:08<00:00, 435.24it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10000/10000 [00:18<00:00, 553.74it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2138/2138 [00:15<00:00, 142.52it/s]
# [2025/01/11 06:53:32] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/11 06:53:32] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/01/11 06:53:34] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/01/11 06:53:35] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0

# %%
# !wget "https://github.com/shreyankg/xkcd-desktop/blob/master/Humor-Sans.ttf?raw=true" -O Humor-Sans.ttf
# !mkdir -p /content/fonts/
# !mv Humor-Sans.ttf /content/fonts/
# Out:
# --2025-01-11 06:53:36--  https://github.com/shreyankg/xkcd-desktop/blob/master/Humor-Sans.ttf?raw=true
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/shreyankg/xkcd-desktop/raw/refs/heads/master/Humor-Sans.ttf [following]
# --2025-01-11 06:53:36--  https://github.com/shreyankg/xkcd-desktop/raw/refs/heads/master/Humor-Sans.ttf
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shreyankg/xkcd-desktop/refs/heads/master/Humor-Sans.ttf [following]
# --2025-01-11 06:53:36--  https://raw.githubusercontent.com/shreyankg/xkcd-desktop/refs/heads/master/Humor-Sans.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25832 (25K) [application/octet-stream]
# Saving to: ‘Humor-Sans.ttf’
#
# Humor-Sans.ttf      100%[===================>]  25.23K  --.-KB/s    in 0.001s
#
# 2025-01-11 06:53:36 (17.1 MB/s) - ‘Humor-Sans.ttf’ saved [25832/25832]

# %%
import cv2
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt

def process_image_with_paddleocr(image_path):
    """
    Process an image using PaddleOCR, display the text with bounding boxes,
    and sort the extracted text row and column-wise.

    :param image_path: Path to the input image.
    :return: List of sorted extracted text with bounding boxes.

    """

    ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=False)



    image = cv2.imread(image_path)

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


    #  Run OCR
    results = ocr.ocr(gray)


    #  Draw bounding boxes and text on the image
    boxes = [line[0] for line in results[0]]
    texts = [line[1][0] for line in results[0]]
    scores = [line[1][1] for line in results[0]]

    # Draw the boxes on the image
    image_for_drawing = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)
    annotated_image = draw_ocr(image_for_drawing, boxes, texts, scores, font_path='Humor-Sans.ttf')

    # Visualize the annotated image
    plt.figure(figsize=(10, 10))
    plt.imshow(annotated_image)
    plt.axis('off')
    plt.title("Text and Bounding Boxes")
    plt.show()

    # Step 4: Sort text row-wise and column-wise
    sorted_results = sorted(
        results[0], key=lambda x: (x[0][0][1], x[0][0][0])
    )  # Sort by Y-coordinate, then X-coordinate

    # Format the output for better readability
    formatted_results = [
        {"text": line[1][0], "confidence": line[1][1], "box": line[0]} for line in sorted_results
    ]

    # Print sorted results
    print("Sorted Text:")
    for item in formatted_results:
        print(f"Text: {item['text']}, Confidence: {item['confidence']:.2f}, Box: {item['box']}")

    return formatted_results

# Example usage
image_path = "/content/form2.jpeg"
sorted_text_data = process_image_with_paddleocr(image_path)
# Out:
# [2025/01/11 07:08:29] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/11 07:08:32] ppocr DEBUG: dt_boxes num : 78, elapsed : 0.5138309001922607
# [2025/01/11 07:08:32] ppocr DEBUG: cls num  : 78, elapsed : 0.2133796215057373
# [2025/01/11 07:08:35] ppocr DEBUG: rec_res num  : 78, elapsed : 3.4241673946380615
# Sorted Text:
# Text: Date, Confidence: 1.00, Box: [[45.0, 134.0], [93.0, 140.0], [90.0, 164.0], [42.0, 158.0]]
# Text: 12, Confidence: 0.93, Box: [[216.0, 152.0], [270.0, 152.0], [270.0, 182.0], [216.0, 182.0]]
# Text: 2, Confidence: 0.98, Box: [[324.0, 155.0], [380.0, 155.0], [380.0, 185.0], [324.0, 185.0]]
# Text: 04, Confidence: 0.79, Box: [[428.0, 158.0], [535.0, 158.0], [535.0, 190.0], [428.0, 190.0]]
# Text: HHNO345678, Confidence: 0.82, Box: [[567.0, 159.0], [844.0, 177.0], [842.0, 207.0], [565.0, 189.0]]
# Text: TITLE M/Ms/Dr.oc, Confidence: 0.71, Box: [[217.0, 186.0], [327.0, 193.0], [326.0, 214.0], [216.0, 208.0]]
# Text: Name, Confidence: 1.00, Box: [[44.0, 189.0], [102.0, 197.0], [99.0, 219.0], [40.0, 212.0]]
# Text: LAST(SUANAL, Confidence: 0.87, Box: [[400.0, 196.0], [477.0, 196.0], [477.0, 211.0], [400.0, 211.0]]
# Text: MER, Confidence: 0.89, Box: [[218.0, 208.0], [270.0, 208.0], [270.0, 237.0], [218.0, 237.0]]
# Text: IPRAKASH, Confidence: 0.90, Box: [[540.0, 214.0], [712.0, 225.0], [711.0, 252.0], [538.0, 241.0]]
# Text: CHANDRA, Confidence: 0.97, Box: [[348.0, 216.0], [543.0, 216.0], [543.0, 241.0], [348.0, 241.0]]
# Text: MIODLENAMI, Confidence: 0.88, Box: [[873.0, 217.0], [939.0, 217.0], [939.0, 232.0], [873.0, 232.0]]
# Text: KRUDCA, Confidence: 0.80, Box: [[838.0, 232.0], [974.0, 235.0], [974.0, 261.0], [837.0, 258.0]]
# Text: Date of Birth, Confidence: 0.94, Box: [[41.0, 262.0], [160.0, 274.0], [158.0, 295.0], [39.0, 283.0]]
# Text: MIODLENAME, Confidence: 0.92, Box: [[896.0, 849.0], [971.0, 849.0], [971.0, 865.0], [896.0, 865.0]]
# Text: Name, Confidence: 1.00, Box: [[20.0, 867.0], [80.0, 867.0], [80.0, 889.0], [20.0, 889.0]]
# Text: MIRI, Confidence: 0.81, Box: [[202.0, 867.0], [267.0, 867.0], [267.0, 901.0], [202.0, 901.0]]
# Text: TAWDE, Confidence: 0.80, Box: [[371.0, 873.0], [503.0, 873.0], [503.0, 898.0], [371.0, 898.0]]
# Text: Contact No., Confidence: 0.92, Box: [[18.0, 942.0], [137.0, 942.0], [137.0, 968.0], [18.0, 968.0]]
# Text: 33456890, Confidence: 0.67, Box: [[201.0, 942.0], [468.0, 937.0], [468.0, 968.0], [201.0, 972.0]]
# Text: Emorgency, Confidence: 0.99, Box: [[18.0, 984.0], [130.0, 984.0], [130.0, 1005.0], [18.0, 1005.0]]
# Text: 4334567890, Confidence: 0.81, Box: [[202.0, 990.0], [484.0, 986.0], [485.0, 1017.0], [203.0, 1022.0]]
# Text: Contact No, Confidence: 0.96, Box: [[18.0, 1007.0], [132.0, 1007.0], [132.0, 1028.0], [18.0, 1028.0]]
# Text: Doctor's Details, Confidence: 0.95, Box: [[20.0, 1039.0], [175.0, 1037.0], [175.0, 1064.0], [20.0, 1066.0]]
# Text: DRTAWDE, Confidence: 0.96, Box: [[201.0, 1076.0], [425.0, 1073.0], [425.0, 1105.0], [201.0, 1108.0]]
# Text: Doctor's Name, Confidence: 0.97, Box: [[14.0, 1082.0], [164.0, 1079.0], [164.0, 1105.0], [14.0, 1108.0]]
# Text: Referring Doctor'sDRHA LDERA, Confidence: 0.91, Box: [[11.0, 1120.0], [498.0, 1118.0], [499.0, 1155.0], [11.0, 1156.0]]
# Text: Name, Confidence: 1.00, Box: [[14.0, 1152.0], [74.0, 1152.0], [74.0, 1174.0], [14.0, 1174.0]]
# Text: Referring Doctor's33457890, Confidence: 0.85, Box: [[11.0, 1183.0], [477.0, 1183.0], [477.0, 1219.0], [11.0, 1219.0]]
# Text: Contact Number, Confidence: 0.97, Box: [[12.0, 1215.0], [176.0, 1209.0], [177.0, 1230.0], [13.0, 1236.0]]

# %%
import cv2
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt

def annotate_image_with_text(image_path):
    """
    Annotates an image with the extracted text directly on its bounding boxes.

    :param image_path: Path to the input image.
    :return: None (displays the annotated image).
    """
    # Initialize PaddleOCR
    ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=False)


    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print("Error: Unable to load image. Check the path.")
        return

    # Convert to RGB for display
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    #  Perform OCR
    results = ocr.ocr(image_path)

    # Step 3: Draw text on bounding boxes
    for line in results[0]:
        # Extract bounding box, text, and confidence
        box = line[0]  # Bounding box
        text = line[1][0]  # Extracted text
        confidence = line[1][1]  # Confidence score

        # Convert coordinates to integers
        box = [[int(point[0]), int(point[1])] for point in box]

        # Draw bounding box
        cv2.polylines(image, [np.array(box)], isClosed=True, color=(0, 255, 0), thickness=2)

        # Put text above the bounding box
        text_position = (box[0][0], box[0][1] - 10)  # Slightly above the top-left corner of the box
        cv2.putText(image, text, text_position, cv2.FONT_HERSHEY_SIMPLEX,
                    fontScale=0.6, color=(255, 0, 0), thickness=1, lineType=cv2.LINE_AA)

    #  Display the annotated image
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title("Annotated Image with Text")
    plt.show()

# Example usage
image_path = "/content/form2.jpeg"
annotate_image_with_text(image_path)
# Out:
# [2025/01/11 07:09:19] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/11 07:09:20] ppocr DEBUG: dt_boxes num : 77, elapsed : 0.31944894790649414
# [2025/01/11 07:09:21] ppocr DEBUG: cls num  : 77, elapsed : 0.24966144561767578
# [2025/01/11 07:09:24] ppocr DEBUG: rec_res num  : 77, elapsed : 3.6170952320098877

# %%
import cv2
from paddleocr import PaddleOCR

def sort_text_row_col(image_path):
    """
    Extracts text from an image and sorts it row-wise and column-wise.

    :param image_path: Path to the input image.
    :return: List of rows, each containing column-sorted text.
    """
    # Initialize PaddleOCR
    ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=False)


    # Perform OCR on the image
    results = ocr.ocr(image_path)

    # Extract bounding boxes and text
    extracted_data = []
    for line in results[0]:
        box = line[0]  # Bounding box
        text = line[1][0]  # Extracted text
        y_center = (box[0][1] + box[2][1]) / 2  # Calculate y-center for row grouping
        x_center = (box[0][0] + box[2][0]) / 2  # Calculate x-center for column sorting
        extracted_data.append((y_center, x_center, text))

    # Sort data by y-center (row-wise), then by x-center (column-wise)
    extracted_data.sort(key=lambda item: (item[0], item[1]))

    # Group data into rows
    row_tolerance = 15  # Tolerance for considering text in the same row
    rows = []
    current_row = []

    for i, data in enumerate(extracted_data):
        if i == 0 or abs(data[0] - extracted_data[i - 1][0]) < row_tolerance:
            current_row.append(data)
        else:
            rows.append(current_row)
            current_row = [data]
    if current_row:
        rows.append(current_row)

    # Sort text within each row by x-center and prepare final sorted output
    sorted_rows = []
    for row in rows:
        row.sort(key=lambda item: item[1])
        sorted_rows.append([item[2] for item in row])

    return sorted_rows

# Example usage
image_path = "/content/form2.jpeg"
sorted_text = sort_text_row_col(image_path)

# Display sorted rows and columns
for i, row in enumerate(sorted_text):
    print(f"Row {i + 1}: {row}")
# Out:
# [2025/01/11 07:09:25] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/01/11 07:09:26] ppocr DEBUG: dt_boxes num : 77, elapsed : 0.2098405361175537
# [2025/01/11 07:09:26] ppocr DEBUG: cls num  : 77, elapsed : 0.1824941635131836
# [2025/01/11 07:09:29] ppocr DEBUG: rec_res num  : 77, elapsed : 2.9623284339904785
# Row 1: ['Date']
# Row 2: ['12', '2', '04', 'HHN345678']
# Row 3: ['Name', 'MER', 'TITLE M/Ms/Dr.oc', 'LAST (SURNAME', 'CHANDRA', 'IPRAKASH', 'FIRST NAM', 'MIODLENAM', 'KRUDCA']
# Row 4: ['Gender', 'Date of Birth', 'Marital Status', 'RS', 'Male', 'CMarried', '07', 'Single', 'Female', '004', 'Others', 'Widowed', 'Divorced', 'AgeYears 0Months 5Days']
# Row 5: ['Occupation']
# Row 6: ['STVDENT', 'ReligionHNDHU']
# Row 7: ['Resi.Address', 'RHINASAR']
# Row 8: ['City/Town', 'BIKANER', 'Pin/Zip Code33403']
# Row 9: ['State', 'RATASTHAN', 'CountryNOA']
# Row 10: ['Nationality', 'INDCAN']
# Row 11: ['Tel.No.(Res.)', '1234567890', 'Office:', '334567890']
# Row 12: ['Mobilo 1', '1334567890', 'Mobile2:', 'STO/1S0Coda']
# Row 13: ['Email-ld', 'CHANDRAOGNAILCON']
# Row 14: ['Responsible Person/Kin Detalls']
# Row 15: ['Relation', 'Father', 'Mother', 'Husband', 'Wife OtherSEF']
# Row 16: ['TITLE (Mc/Ms/Dcelc', 'AST (SURNAME)', 'FIRST NAME', 'MIOOLENAME']
# Row 17: ['Name', 'MRI', 'TAWDE']
# Row 18: ['Contact No.', '133456890']
# Row 19: ['Emorgency', 'Contact No', '4334567890']
# Row 20: ["Doctor's Details"]
# Row 21: ["Doctor's Name", 'DRTAWDE']
# Row 22: ["Referring Doctor'sDRHA LDERA"]
# Row 23: ['Name']
# Row 24: ["Referring Doctor's33457890"]
# Row 25: ['Contact Number']

# %%
ocr_text = " ".join([" ".join(row) for row in sorted_text])

output = pipeline(
    ocr_text,
    max_length=300,
    min_length=30,
    do_sample=False,
    num_return_sequences=1,
)

# Extract the generated text
generated_summary = output[0]["generated_text"]

# Print the summary line by line
print("Summary Line by Line:")
for line in generated_summary.split(". "):  # Split by sentence
    print(line)

# Save the summary to a JSON file
summary_json = {"summary": generated_summary.split(". ")}  # Line-by-line summary
with open("summary.json", "w") as json_file:
    json.dump(summary_json, json_file, indent=4)

print("Summary saved to summary.json")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Summary Line by Line:
# Date 12 2 04 HHN345678 Name MER TITLE M/Ms/Dr.oc LAST (SURNAME CHANDRA IPRAKASH FIRST NAM MIODLENAM KRUDCA Gender Date of Birth Marital Status RS Male CMarried 07 Single Female 004 Others Widowed Divorced AgeYears 0Months 5Days Occupation STVDENT ReligionHNDHU Resi.Address RHINASAR City/Town BIKANER Pin/Zip Code33403 State RATASTHAN CountryNOA Nationality INDCAN Tel.No.(Res.) 1234567890 Office: 334567890 Mobilo 1 1334567890 Mobile2: STO/1S0Coda Email-ld CHANDRAOGNAILCON Responsible Person/Kin Detalls Relation Father Mother Husband Wife OtherSEF TITLE (Mc/Ms/Dcelc AST (SURNAME) FIRST NAME MIOOLENAME Name MRI TAWDE Contact No
# 133456890 Emorgency Contact No 4334567890 Doctor's Details Doctor's Name DRTAWDE Referring Doctor'sDRHA LDERA Name Referring Doctor's33457890 Contact Number 334567890 Referring Doctor's Address 334567890 Referring Doctor's City/Town 334567890 Referring Doctor's State 334567890 Referring Doctor's Country 334567890 Referring Doctor's Pin/Zip Code 334567890
# Summary saved to summary.json

# %%
output[0]["generated_text"]
# Out:
# "Date 12 2 04 HHN345678 Name MER TITLE M/Ms/Dr.oc LAST (SURNAME CHANDRA IPRAKASH FIRST NAM MIODLENAM KRUDCA Gender Date of Birth Marital Status RS Male CMarried 07 Single Female 004 Others Widowed Divorced AgeYears 0Months 5Days Occupation STVDENT ReligionHNDHU Resi.Address RHINASAR City/Town BIKANER Pin/Zip Code33403 State RATASTHAN CountryNOA Nationality INDCAN Tel.No.(Res.) 1234567890 Office: 334567890 Mobilo 1 1334567890 Mobile2: STO/1S0Coda Email-ld CHANDRAOGNAILCON Responsible Person/Kin Detalls Relation Father Mother Husband Wife OtherSEF TITLE (Mc/Ms/Dcelc AST (SURNAME) FIRST NAME MIOOLENAME Name MRI TAWDE Contact No. 133456890 Emorgency Contact No 4334567890 Doctor's Details Doctor's Name DRTAWDE Referring Doctor'sDRHA LDERA Name Referring Doctor's33457890 Contact Number 334567890 Referring Doctor's Address 334567890 Referring Doctor's City/Town 334567890 Referring Doctor's State 334567890 Referring Doctor's Country 334567890 Referring Doctor's Pin/Zip Code 334567890"

# %%
{
    "summary": [
        "Date 12 2 04 HHN345678 Name MER TITLE M/Ms/Dr.oc LAST (SURNAME CHANDRA IPRAKASH FIRST NAM MIODLENAM KRUDCA Gender Date of Birth Marital Status RS Male CMarried 07 Single Female 004 Others Widowed Divorced AgeYears 0Months 5Days Occupation STVDENT ReligionHNDHU Resi.Address RHINASAR City/Town BIKANER Pin/Zip Code33403 State RATASTHAN CountryNOA Nationality INDCAN Tel.No.(Res.) 1234567890 Office: 334567890 Mobilo 1 1334567890 Mobile2: STO/1S0Coda Email-ld CHANDRAOGNAILCON Responsible Person/Kin Detalls Relation Father Mother Husband Wife OtherSEF TITLE (Mc/Ms/Dcelc AST (SURNAME) FIRST NAME MIOOLENAME Name MRI TAWDE Contact No",
        "133456890 Emorgency Contact No 4334567890 Doctor's Details Doctor's Name DRTAWDE Referring Doctor'sDRHA LDERA Name Referring Doctor's33457890 Contact Number 334567890 Referring Doctor's Address 334567890 Referring Doctor's City/Town 334567890 Referring Doctor's State 334567890 Referring Doctor's Country 334567890 Referring Doctor's Pin/Zip Code 334567890"
    ]
}
# Out:
# {'summary': ['Date 12 2 04 HHN345678 Name MER TITLE M/Ms/Dr.oc LAST (SURNAME CHANDRA IPRAKASH FIRST NAM MIODLENAM KRUDCA Gender Date of Birth Marital Status RS Male CMarried 07 Single Female 004 Others Widowed Divorced AgeYears 0Months 5Days Occupation STVDENT ReligionHNDHU Resi.Address RHINASAR City/Town BIKANER Pin/Zip Code33403 State RATASTHAN CountryNOA Nationality INDCAN Tel.No.(Res.) 1234567890 Office: 334567890 Mobilo 1 1334567890 Mobile2: STO/1S0Coda Email-ld CHANDRAOGNAILCON Responsible Person/Kin Detalls Relation Father Mother Husband Wife OtherSEF TITLE (Mc/Ms/Dcelc AST (SURNAME) FIRST NAME MIOOLENAME Name MRI TAWDE Contact No',
#   "133456890 Emorgency Contact No 4334567890 Doctor's Details Doctor's Name DRTAWDE Referring Doctor'sDRHA LDERA Name Referring Doctor's33457890 Contact Number 334567890 Referring Doctor's Address 334567890 Referring Doctor's City/Town 334567890 Referring Doctor's State 334567890 Referring Doctor's Country 334567890 Referring Doctor's Pin/Zip Code 334567890"]}
